# %%
# displays plots in this notebook
# %matplotlib inline 

# Since we are in the ./examples folder, add the root folder (../) to the path
import sys
sys.path.append('../')

from src.spectrum import import_spd

# Get the SPDs
dyson_2700 = import_spd('../CSVs/dyson/Dyson_2700.csv', 'Dyson 2700K', normalize=True)
dyson_6500 = import_spd('../CSVs/dyson/Dyson_6500.csv', 'Dyson 6500K', normalize=True)

from src.plot import plot_spectrum, plot_multi_spectrum

plot_spectrum(dyson_2700, hideyaxis=True, melanopic_curve=True, melanopic_stimulus=True, title='Dyson Lightcycle 2700K', filename='../out/Dyson_2700.png')
plot_spectrum(dyson_6500, hideyaxis=True, melanopic_curve=True, melanopic_stimulus=True, title='Dyson Lightcycle 6500K', filename='../out/Dyson_6500.png')
# Out:
# /usr/local/lib/python3.7/site-packages/colour/utilities/verbose.py:141: ColourWarning: "domain" and "range" variables have different size, "range" variable will be resized to "domain" variable shape!
#   warn(*args, **kwargs)
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
from src.r_values import plot_r_values

r_vals_2700 = {
    "R1":	91.505455,
    "R2":	94.321884,
    "R3":	96.436676,
    "R4":	92.784698,
    "R5":	91.253769,
    "R6":	93.816368,
    "R7":	92.236389,
    "R8":	80.238365,
    "R9":	54.929466,
    "R10":	86.446983,
    "R11":	93.728653,
    "R12":	82.747665,
    "R13":	92.023804,
    "R14":	97.441734,
    "R15":	86.684669
}

r_vals_6500 = {
    "R1":	86.17952,
    "R2":	90.50441,
    "R3":	93.914978,
    "R4":	87.689781,
    "R5":	86.508194,
    "R6":	86.588112,
    "R7":	93.220596,
    "R8":	80.662025,
    "R9":	41.479633,
    "R10":	77.902252,
    "R11":	86.883781,
    "R12":	86.883781,
    "R13":	87.12056,
    "R14":	97.749878,
    "R15":	82.382103
}

plot_r_values(r_vals_2700, title='R-Values: Dyson Lightcycle 2700K', filename='../out/Dyson_2700_r_vals.png')
plot_r_values(r_vals_6500, title='R-Values: Dyson Lightcycle 6500K', filename='../out/Dyson_6500_r_vals.png')
