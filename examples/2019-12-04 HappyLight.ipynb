# %%
###### displays plots in this notebook
# %matplotlib inline 

# Since we are in the ./examples folder, add the root folder (../) to the path
import sys
sys.path.append('../')

from src.spectrum import import_spd_batch, import_spd
from src.plot import plot_spectrum, plot_multi_spectrum

# Get the SPDs
spds = import_spd_batch('../CSVs/2019_happylight/', photometer='uprtek')
incandescent = import_spd('../CSVs/Incandescent.csv', 'Incandescent', normalize=True)
spds = import_spd_batch('../CSVs/2019_guangzhou/', photometer='uprtek')
# Out:
# Imported the following SPDs:
# Verilux HappyLight Lumi
# Imported the following SPDs:
# Mosquito Lamp
# Bridgelux Thrive 2700K
# EStar 97CRI 5000K
# Philips Warm Glow 2700K
# Bridgelux Thrive 4000K
# EStar 97CRI 4000K
# Bridgelux Thrive 5000K
# Philips Warm Glow 2200K
# Bridgelux Thrive 3000K
# EStar 94CRI 2700K
# Bridgelux Thrive 6500K
# EStar 97CRI 3000K
# /usr/local/lib/python3.7/site-packages/colour/utilities/verbose.py:141: ColourWarning: "domain" and "range" variables have different size, "range" variable will be resized to "domain" variable shape!
#   warn(*args, **kwargs)

# %%
plot_spectrum(spds['Verilux HappyLight Lumi'], title='Verilux HappyLight Lumi', melanopic_curve=True, hideyaxis=True, filename='../out/happylight_lumi.png')
# Out:
# /usr/local/lib/python3.7/site-packages/colour/utilities/verbose.py:141: ColourWarning: "domain" and "range" variables have different size, "range" variable will be resized to "domain" variable shape!
#   warn(*args, **kwargs)
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
from src.r_values import plot_r_values

r_vals = {
    "R1":	85.308853,
    "R2":	88.172699,
    "R3":	90.26001,
    "R4":	86.95977,
    "R5":	86.035782,
    "R6":	83.967712,
    "R7":	88.979591,
    "R8":	76.121796,
    "R9":	30.650505,
    "R10":	72.441811,
    "R11":	87.705978,
    "R12":	67.077461,
    "R13":	85.673515,
    "R14":	95.472832,
    "R15":	80.832024
}

plot_r_values(r_vals, title='R-Values: Verilux HappyLight Lumi', filename='../out/happylight_rvals.png')

# %%
plot_spectrum(incandescent, title='Incandescent', melanopic_curve=True, hideyaxis=True, filename='../out/incandescent.png')
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
plot_spectrum(spds['Bridgelux Thrive 6500K'], title='6500K Enhanced-Spectrum LED', melanopic_curve=True, hideyaxis=True, filename='../out/enhanced_0.png')
plot_spectrum(spds['EStar 97CRI 5000K'], title='5000K Enhanced-Spectrum LED', melanopic_curve=True, hideyaxis=True, filename='../out/enhanced_1.png')
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
