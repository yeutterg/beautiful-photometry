# %%
# displays plots in this notebook
# %matplotlib inline 

# Since we are in the ./examples folder, add the root folder (../) to the path
import sys
sys.path.append('../')

from src.spectrum import import_spd_batch, import_spd
from src.plot import plot_spectrum, plot_multi_spectrum

# Get the SPDs
spds = import_spd_batch('../CSVs/2019_lightfair/', photometer='uprtek')
dyson_2700 = import_spd('../CSVs/dyson/Dyson_2700.csv', 'Typical 90 CRI 2700K', normalize=True)

# plot_spectrum(dyson_2700, hideyaxis=True, melanopic_curve=True, melanopic_stimulus=True, title='Dyson Lightcycle 2700K', filename='../out/Dyson_2700.png')
# plot_spectrum(dyson_6500, hideyaxis=True, melanopic_curve=True, melanopic_stimulus=True, title='Dyson Lightcycle 6500K', filename='../out/Dyson_6500.png')
# Out:
# Imported the following SPDs:
# Osram Yellow
# Yuji 1800K
# Osram PC Yellow
# Nichia Optisolis 3000K
# Seoul Sunlike 3000K
# Keyart Orange
# Aurea Day 5700K
# Cedar 2200K Outdoor
# Bios Low Blue 2
# Nichia 80 CRI
# Bios Low Blue 1
# Osram Osconiq
# Nichia Vitasolis Cool
# Lumileds PC Amber
# Soraa Vivid 2
# Nichia Optisolis 5000K
# Bios SkyBlue 3300K
# Lumileds Amber
# Soraa Vivid 3
# Aurea Night
# Soraa Vivid 1
# Samsung Relaxing
# Soraa Vivid 4
# Yuji 5000K
# Samsung Energizing 4000K
# Keyart Yellow Coat

# %%
# Amber
plot_multi_spectrum([spds['Lumileds Amber'], spds['Lumileds PC Amber'], spds['Osram Yellow'], spds['Osram PC Yellow']], title='Amber LEDs', melanopic_curve=True, hideyaxis=True)
# Out:
# /usr/local/lib/python3.7/site-packages/colour/utilities/verbose.py:141: ColourWarning: "domain" and "range" variables have different size, "range" variable will be resized to "domain" variable shape!
#   warn(*args, **kwargs)
# /usr/local/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# "Flat" enchanced spectrum LEDs
plot_multi_spectrum([spds['Seoul Sunlike 3000K'], spds['Nichia Optisolis 3000K'], spds['Nichia Optisolis 5000K'], dyson_2700], title='"Flat" Enhanced-Spectrum LEDs', melanopic_curve=True, hideyaxis=True)

# %%
# High Melanopic LEDs
plot_multi_spectrum([spds['Bios SkyBlue 3300K'], spds['Samsung Energizing 4000K'], spds['Nichia Vitasolis 5000K'], spds['Aurea Day 5700K']], title='High-Melanopic LEDs', melanopic_curve=True, hideyaxis=True)
